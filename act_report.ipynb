# %% [markdown]
# ## Report: act_report

# %% [markdown]
# After Data Wrangling, the cleaned data was stored with a file name: twitter-archive-master.csv. My analyses and visualization is one three research questions as follows:
#    - the most common type of dog stages
#    - the one tweet with most likes
#    - some properties of tweets with most likes
#
# #### 1. The most common type of dog stages
#
# A pie chart showing the plot of value count of the different dog stage type was used to answer this question. There are four stages of dogs; viz, doggo, floofer, pupper and puppo. In this dataset, there are cases where there are no dog stage value, such observations are recorded as None. From the chart above, we can see that there are several observations where the dog stage is None; the value is 1319. The pupper dog stage is the most occured with value counts of 154, followed by value count of 60, then puppo with value count of 54, lastly floofer with value count of 12

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2. The tweet with most likes.
#
# A bar chart showing the plot of the top 10 largest tweets in terms of favorite_count was used to answer this question. This is the row index of the dataframe ploted against the favorite_count column. The row index of 283 has the higest favorite count, followed by row 681, 55,365 etc

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Tweet
# tweet: "Here's a super supportive puppo participating in the Toronto  #WomensMarch today. 13/10 https://t.co/nTz3FtorBc",
#
# created at : 2017-01-21 18:26:02 +0000
#
# ![images%20%289%29.jpeg](attachment:images%20%289%29.jpeg)
#
# A user with the twitter ID 822872901745569793 has the most favorite_count.

# %% [markdown]
# #### 3 some properties of tweets with most likes

# %% [markdown]
# A sample of top 100 highest tweets in terms of favorite_count was analyzed, I noticed that:
#    - the rating denominator consists of only two unique values of 10 and 11. The value count for 10 is 99 while that of 11 is 1.
#    - the rating numerator consists of few unique values (13, 12, 11, 14, 10, 5, 9). The value count are 56, 21, 11, 6, 4, 1 ,1 respectively.

# %% [markdown]
# ![images%20%2811%29.jpeg](attachment:images%20%2811%29.jpeg)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![images%20%2812%29.jpeg](attachment:images%20%2812%29.jpeg)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Another insights I discovered is that the retweet_count column and favorite_column are the same.
